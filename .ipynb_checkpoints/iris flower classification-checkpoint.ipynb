# %% [markdown]
# # LetsGrowMore
# ## Data Science Internship
# ### 02 Beginner Level Task: Iris flower classificstion with machine learning

# %%
# Importing the needed libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, plot_confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %matplotlib inline

# %%
#Loading and reading the dataset
data = pd.read_csv('Iris.csv')

# %% [markdown]
# ### Eploring the data

# %%
df = data

# %%
#Removing the irrelevant column and also renaming all other columns
df = df.drop('Id', axis = 1)
df.columns = ['sepal_length', 'sepal_width', 'petal_length', 'petal_width','species']

# %%
# Understanding the nature of the dataset
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 5.3+ KB

# %%
df.shape
# Out:
# (150, 5)

# %%
#checking for null values
df.isnull().sum()
# Out:
# sepal_length    0
# sepal_width     0
# petal_length    0
# petal_width     0
# species         0
# dtype: int64

# %%
df.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
df.nunique()
# Out:
# sepal_length    35
# sepal_width     23
# petal_length    43
# petal_width     22
# species          3
# dtype: int64

# %%
df['species'].value_counts()
# Out:
# Iris-setosa        50
# Iris-virginica     50
# Iris-versicolor    50
# Name: species, dtype: int64

# %%
df.min() # Minimum values in each column
# Out:
# sepal_length            4.3
# sepal_width               2
# petal_length              1
# petal_width             0.1
# species         Iris-setosa
# dtype: object

# %%
df.max() # Maximum values in each column
# Out:
# sepal_length               7.9
# sepal_width                4.4
# petal_length               6.9
# petal_width                2.5
# species         Iris-virginica
# dtype: object

# %% [markdown]
# ## Data visualization

# %%
sns.countplot(x = df['species'])
# Out:
# <AxesSubplot:xlabel='species', ylabel='count'>

# %%
sns.pairplot(df, hue = 'species', height = 4)
plt.show()

# %%
plt.plot(df.species, df.sepal_length, label = "Sepal Length")
plt.plot(df.species, df.sepal_width, label = "Sepal width")
plt.plot(df.species, df.petal_length, label = "Petal Length")
plt.plot(df.species, df.petal_width, label = "Petal Width")

plt.title("Plotting the relationship between the columns")
plt.legend()
plt.show()

# %%
plt.scatter(df.species, df.sepal_length)

# %%
plt.scatter(data = df, x = 'species', y = 'sepal_width')

# %%
plt.scatter(data = df, x = 'species', y = 'petal_length')

# %%
plt.scatter(data = df, x = 'species', y = 'petal_width')

# %% [markdown]
# ### Data preprocessing

# %%
df['species'].unique()
# Out:
# array(['Iris-setosa', 'Iris-versicolor', 'Iris-virginica'], dtype=object)

# %%
mapp = {'Iris-setosa': 0, 'Iris-versicolor': 1, 'Iris-virginica': 2}
df['species'] = df['species'].map(mapp) #Label encoder can alternatively be used
df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width  species
# 0             5.1          3.5           1.4          0.2        0
# 1             4.9          3.0           1.4          0.2        0
# 2             4.7          3.2           1.3          0.2        0
# 3             4.6          3.1           1.5          0.2        0
# 4             5.0          3.6           1.4          0.2        0
# ..            ...          ...           ...          ...      ...
# 145           6.7          3.0           5.2          2.3        2
# 146           6.3          2.5           5.0          1.9        2
# 147           6.5          3.0           5.2          2.0        2
# 148           6.2          3.4           5.4          2.3        2
# 149           5.9          3.0           5.1          1.8        2
#
# [150 rows x 5 columns]

# %%
df['species'].value_counts()
# Out:
# 0    50
# 1    50
# 2    50
# Name: species, dtype: int64

# %%
# defining the predictor columns and target column
# x is the predictor
# y is the target variable
x = df.drop('species', axis = 1)
y = df['species']

# %%
#splitting the dataset into train and test set
x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.3)

# %% [markdown]
# ### Training different models

# %%
rf = RandomForestClassifier()
rf.fit(x_train, y_train)
# Out:
# RandomForestClassifier()

# %%
lr = LogisticRegression()
lr.fit(x_train, y_train)
# Out:
# LogisticRegression()

# %%
dt = DecisionTreeClassifier()
dt.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
def report(model):
    y_pred = model.predict(x_test)
    print(f"The accuracy of {type(model).__name__} is {round(accuracy_score(y_pred, y_test) * 100)}%")
    plot_confusion_matrix(model, x_test, y_test)

# %%
report(dt)
# Out:
# The accuracy of DecisionTreeClassifier is 96%

# %%
report(gaus)
# Out:
# The accuracy of GaussianNB is 93%

# %%
report(rf)
# Out:
# The accuracy of RandomForestClassifier is 89%

# %%
report(lr)
# Out:
# The accuracy of LogisticRegression is 96%

# %% [markdown]
# #### Summary

# %% [markdown]
# Logistics Regression is the best model
